# %%
import numpy as np
import math
import decimal
import pandas as pd

def round_well(num,p=0): return mi_round(mi_round(num,p+5),p)

def mi_round(num,p=0):
    expoN=num*10**p
    if abs(expoN)-abs(math.floor(expoN))<0.5:
        return math.floor(expoN)/10**p
    return math.ceil(expoN)/10**p

def m_euler(f, x0, y0, h, n):
	x=[x0]
	y=[y0]
	for i in range(n):
		x.append(round_well(x[i]+h,3))
		y.append(round_well(y[i]+h*f(x[i], y[i]),3))
	X, Y=np.array(x), np.array(y)
	return X, Y

def m_euler_gauss(f, x0, y0, h, n):
	x=[x0]
	y=[y0]
	yE=[0]
	for i in range(n):
		x_next=round_well(x[i]+h,3)
		p=round_well(y[i]+h*f(x[i], y[i]),3)
		yE.append(round_well(y[i]+h*f(x[i], y[i]),3))
		x.append(x_next)
		y.append(round_well(y[i]+(h/2)*(f(x[i], y[i])+f(x_next, p)),3))
	X, Y, Z=np.array(x), np.array(y), np.array(yE)
	return X, Y,Z
 
def run_kut2(f,x,y,h):
	K1 = round_well(h*f(x, y),3)
	K2 = round_well(h*f(x + h, y + K1), 3)
	return  K1, K2

def m_run_kut2(f,x,y, x_final,h):
	X=[x]
	Y=[y]
	K1,K2=[], []
	while x<=x_final:
		k1,k2=run_kut2(f,x,y,h)
		y=round_well(y+(0.5)*(k1+k2),3)
		x=round_well(x+h,3)
		K1.append(k1)
		K2.append(k2)
		X.append(x)
		Y.append(y)
	return np.array(X),np.array(Y), np.array(K1), np.array(K2)



def run_kut3(f,x,y,h):
	K1 = round_well(h*f(x, y),3)
	K2 = round_well(h*f(x + h/2.0, y + K1/2.0), 3)
	K3 = round_well(h*f(x + h, y - K1 + 2.0*K2),3)
	return  K1, K2, K3

def m_run_kut3(f,x,y, x_final,h):
	X=[x]
	Y=[y]
	K1,K2,K3=[], [], []
	while x<=x_final:
		k1,k2,k3=run_kut3(f,x,y,h)
		y=round_well(y+(1/6.0)*(k1+4*k2+k3),3)
		x=round_well(x+h,3)
		K1.append(k1)
		K2.append(k2)				
		K3.append(k3)
		X.append(x)
		Y.append(y)
	return np.array(X),np.array(Y), np.array(K1), np.array(K2), np.array(K3)

def run_kut4(f,x,y,h):
	K1 = round(round_well(h*f(x, y),5),3)
	K2 = round_well(h*f(x + h/2.0, y + K1/2.0), 3)
	K3 = round_well(h*f(x + h/2.0, y + K2/2.0),3)
	K4 = round_well(h*f(x + h, y+K3),3)
	return  K1, K2, K3, K4

def m_run_kut4(f,x,y, x_final,h):
	X=[x]
	Y=[y]
	K1,K2,K3, K4=[], [], [], []
	while x<=x_final:
		k1,k2,k3, k4=run_kut4(f,x,y,h)
		y=round_well(y+(1/6.0)*(k1+2*k2+2*k3+k4),3)
		x=round_well(x+h,3)
		K1.append(k1)
		K2.append(k2)				
		K3.append(k3)
		K4.append(k4)
		X.append(x)
		Y.append(y)
	return np.array(X),np.array(Y), np.array(K1), np.array(K2), np.array(K3), np.array(K4)

# %%
#--------------------------------------------------------

def f(x,y): return x+2*x*y



x,y=m_euler(f, 1, 3, 0.5,5)

#solucion=np.round(2*np.exp(np.sin(x)),3)
solucion=np.round((7/2)*np.exp(x**2-1)-0.5,3)

print('\n Euler\n')

print("i\t xi\t yi")
for i in range(len(x)): print(f"{i}\t {x[i]}\t {y[i]} \t {solucion[i]}\t {round_well(abs(solucion[i]-y[i]),3)}")

print('\n Euler-Gauss\n')

x,y, ye=m_euler_gauss(f, 1, 3, 0.5,5)
print("\n\ni\t xi\t yi\t y_e")
for i in range(len(x)): print(f"{i}\t {x[i]}\t {y[i]} \t{ye[i]}\t {round_well(abs(solucion[i]-y[i]),3)}")

    
    

x,y,k1,k2=m_run_kut2(f, 1, 3, 3.5 ,0.5)
np.append(k1,0)
np.append(k2,0)
np.append(k1,0)
np.append(k2,0)



data = {'x': x, 'y': y, 'k1': k1, 'k2': k2}
df=pd.DataFrame(data)

m=min(len(x),len(y),len(k1))

print('\nRK2\n')
for i in range(m): 
    print(f" i={i}\n xi={x[i]}\n yi={y[i]}\n k1={k1[i]}\n k2={k2[i]}\n error={round_well(abs(solucion[i]-y[i]),3)}\n\n")
print(f'y_{m}={y[m]}')


x,y,k1,k2,k3=m_run_kut3(f, 1, 3, 3.5 ,0.5)

m=min(len(x),len(y),len(k1))

print('\nRK3\n')
for i in range(m): 
    print(f" i={i}\n xi={x[i]}\n yi={y[i]}\n k1={k1[i]}\n k2={k2[i]}\n k3={k3[i]}\n error={round_well(abs(solucion[i]-y[i]),3)}\n\n")
print(f'y_{m}={y[m]}')


x,y,k1,k2,k3, k4=m_run_kut4(f, 1, 3, 4 ,0.5)

m=min(len(x),len(y),len(k1))

print('\nRK4\n')
for i in range(m): 
    print(f" i={i}\n xi={x[i]}\n yi={y[i]}\n k1={k1[i]}\n k2={k2[i]}\n k3={k3[i]}\n k4={k4[i]}\n error={round_well(abs(solucion[i]-y[i]),3)}\n\n")
# Out:
#  Euler
#
# i	 xi	 yi
# 0	 1.0	 3.0 	 3.0	 0.0
# 1	 1.5	 6.5 	 11.716	 5.216
# 2	 2.0	 17.0 	 69.799	 52.799
# 3	 2.5	 52.0 	 666.482	 614.482
# 4	 3.0	 183.25 	 10432.853	 10249.603
# 5	 3.5	 734.5 	 269079.219	 268344.719
#
#  Euler-Gauss
#
#
#
# i	 xi	 yi	 y_e
# 0	 1.0	 3.0 	0.0	 0.0
# 1	 1.5	 10.0 	6.5	 1.716
# 2	 2.0	 44.125 	25.75	 25.674
# 3	 2.5	 256.094 	133.375	 410.388
# 4	 3.0	 1923.955 	897.579	 8508.898
# 5	 3.5	 18281.823 	7697.32	 250797.396
# 6
# 6
# 7
# 7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-84b8077ab04f> in <module>
#      35
#      36 data = {'x': x, 'y': y, 'k1': k1, 'k2': k2}
# ---> 37 df=pd.DataFrame(data)
#      38
#      39 m=min(len(x),len(y),len(k1))
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df
# Out:
#      x           y
# 0  1.0       3.000
# 1  1.5      10.000
# 2  2.0      44.125
# 3  2.5     256.094
# 4  3.0    1923.955
# 5  3.5   18281.823
# 6  4.0  214816.797
